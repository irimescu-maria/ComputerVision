# %%
'''
Detectare de obiecte in imagini

'''
from imageai.Detection import ObjectDetection
import os
import matplotlib.image as mpimg
# %matplotlib inline
execution_path = os.getcwd()
detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath("D:/Downloads/resnet50_coco_best_v2.0.1.h5")
detector.loadModel()
img = mpimg.imread(os.path.join(execution_path , "IMG-20191118-WA0084.jpg"))

#plt.imshow(img)
#plt.axis("off")

import matplotlib.pyplot as plt #interfata pentru afisare de imagini
detections = detector.detectObjectsFromImage(
input_image=os.path.join(execution_path , "256x256bb.jpg"),
output_image_path=os.path.join(execution_path , "pozaAdnotata.jpg"))
img = mpimg.imread(os.path.join(execution_path , "pozaAdnotata.jpg"))
plt.imshow(img)
plt.axis("off")
for eachObject in detections:
    print(eachObject["name"] , " : " , eachObject["percentage_probability"] )
# Out:
# tracking <tf.Variable 'Variable_20:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_21:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_22:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_23:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_24:0' shape=(9, 4) dtype=float32> anchors
# WARNING:tensorflow:From C:\Users\Maria\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# handbag  :  56.96249604225159
# person  :  89.73026275634766
# bench  :  55.76638579368591
# bench  :  76.24928951263428
